# %% [markdown]
# # Titre
# Voici ma partie 1 du day 7

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
my_list = [10, 20, 30, 40, 50]
my_list
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# # La cellule calcule et affiche dans un tuple :
# o La somme de toutes les valeurs
# o La moyenne arrondie à la deuxième décimale
# o La valeur maximale
# o La valeur minimale

# %%
somme = sum(my_list)
moyenne = round(sum(my_list) / len(my_list), 2)
valmax = max(my_list)
valmin = min(my_list)
(somme, moyenne, valmax, valmin)
# Out:
# (150, 30.0, 50, 10)

# %%
import pandas as pd

# %time df = pd.read_csv('flights.csv')
# Out:
# CPU times: user 201 ms, sys: 21.8 ms, total: 223 ms
# Wall time: 223 ms

# %%
# %%timeit -r 20 -n 25

df['FL_DATE'].value_counts()

df.groupby('FL_DATE')['ARR_DELAY'].mean()

df.sort_values(by='DEP_DELAY', ascending=False).head(1000)
# Out:
# 121 ms ± 2.19 ms per loop (mean ± std. dev. of 20 runs, 25 loops each)

# %%
import ipywidgets as widgets
from IPython.display import display

slider = widgets.IntSlider(
    value=20,
    min=0,
    max=100,
    step=5,
    description='Valeur:',
    continuous_update=True
    )

display(slider)
slider.value
# Out:
# IntSlider(value=20, description='Valeur:', step=5)
# 20
